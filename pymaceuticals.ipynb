# %% [markdown]
# ## Observations and Insights
#
# ### Observations:
#
# * Capomulin and Ramicane have lower final tumor volumes than Infubinol and Ceftamin.  Both also have a greater data volume of timepoints.
# * Mouse weight and average tumor volume within the Capomulin regimen are positively correlated.
# * The tumor volume of Mouse ID y793 decreased over the course of the Capomulin regimen.
#
# ### Insights:
#
# * Capomulin seems effective in reducing the tumor volume of squamous cell carcinoma over a period of 45 days, as supported by the mean Tumor Volume and by Mouse ID y793.
# * Ramicane appears to have a similar effectiveness, and may be a strong competator to Capomulin.
# * To make a stronger case, further analysis will be required.  This analysis would need to at least examine the of change in tumor volume over time, explore the relationship of weight as a factor, as well as age and sex.
#
# ### Notes:
#
# * To facilitate stronger accuracy in comparisons, all Tumor Volume ranges in plots have a lower bound of 20 mm3.

# %% [markdown]
# # Analysis

# %%
#import dependencies
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import numpy as np

#read in mouse data and study results
mouse_metadata = pd.read_csv("data/Mouse_metadata.csv")
study_results = pd.read_csv("data/Study_results.csv")

#combine mouse and study data into one dataframe
mouse_study_data = pd.merge(mouse_metadata, study_results, on= 'Mouse ID', how= 'outer')

#preview combined frame
mouse_study_data.head(25)
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0      k403     Ramicane    Male          21          16          0
# 1      k403     Ramicane    Male          21          16          5
# 2      k403     Ramicane    Male          21          16         10
# 3      k403     Ramicane    Male          21          16         15
# 4      k403     Ramicane    Male          21          16         20
# 5      k403     Ramicane    Male          21          16         25
# 6      k403     Ramicane    Male          21          16         30
# 7      k403     Ramicane    Male          21          16         35
# 8      k403     Ramicane    Male          21          16         40
# 9      k403     Ramicane    Male          21          16         45
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# 13     s185    Capomulin  Female           3          17         15
# 14     s185    Capomulin  Female           3          17         20
# 15     s185    Capomulin  Female           3          17         25
# 16     s185    Capomulin  Female           3          17         30
# 17     s185    Capomulin  Female           3          17         35
# 18     s185    Capomulin  Female           3          17         40
# 19     s185    Capomulin  Female           3          17         45
# 20     x401    Capomulin  Female          16          15          0
# 21     x401    Capomulin  Female          16          15          5
# 22     x401    Capomulin  Female          16          15         10
# 23     x401    Capomulin  Female          16          15         15
# 24     x401    Capomulin  Female          16          15         20
#
#     Tumor Volume (mm3)  Metastatic Sites
# 0            45.000000                 0
# 1            38.825898                 0
# 2            35.014271                 1
# 3            34.223992                 1
# 4            32.997729                 1
# 5            33.464577                 1
# 6            31.099498                 1
# 7            26.546993                 1
# 8            24.365505                 1
# 9            22.050126                 1
# 10           45.000000                 0
# 11           43.878496                 0
# 12           37.614948                 0
# 13           38.177232                 0
# 14           36.866876                 0
# 15           33.949940                 0
# 16           32.959671                 1
# 17           28.328531                 1
# 18           25.472143                 1
# 19           23.343598                 1
# 20           45.000000                 0
# 21           45.473753                 0
# 22           39.113891                 0
# 23           39.776250                 0
# 24           36.065835                 0

# %%
#check the number of mice
mouse_count = len(mouse_study_data['Mouse ID'].unique())
mouse_count
# Out:
# 249

# %%
#determine duplicate mouse id
mouse_study_data['Mouse ID'].value_counts()
# Out:
# g989    13
# l661    10
# s565    10
# x581    10
# j296    10
#         ..
# v199     1
# u153     1
# t573     1
# o848     1
# b447     1
# Name: Mouse ID, Length: 249, dtype: int64

# %%
#obtain duplicate mouse id data
duplicate_id = mouse_study_data.loc[mouse_study_data['Mouse ID'] == 'g989',:]
duplicate_id
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# 911           47.570392                 0
# 912           51.745156                 0
# 913           49.880528                 0
# 914           51.325852                 1
# 915           53.442020                 0
# 916           55.326122                 1
# 917           54.657650                 1
# 918           56.045564                 1
# 919           59.082294                 1
# 920           62.570880                 2

# %%
#create clean dataframe by dropping duplicate mouse id
mouse_study_clean = mouse_study_data.loc[mouse_study_data['Mouse ID'] != 'g989',:]

# %%
#confirm number of mice in clean dataframe
mouse_count = len(mouse_study_clean['Mouse ID'].unique())
mouse_count
# Out:
# 248

# %%
#create object of study data by drug administered
study_grouped_drug = mouse_study_clean.groupby('Drug Regimen')

#create series of statistics describing tumor volume
drug_means = study_grouped_drug['Tumor Volume (mm3)'].mean()
drug_medians = study_grouped_drug['Tumor Volume (mm3)'].median()
drug_variance = study_grouped_drug['Tumor Volume (mm3)'].var()
drug_stdev = study_grouped_drug['Tumor Volume (mm3)'].std()
drug_sem = study_grouped_drug['Tumor Volume (mm3)'].sem()

#create summary dataframe
drug_stats = pd.DataFrame(
    {'Mean': drug_means,
    'Median': drug_medians,
    'Variance': drug_variance,
    'Standard Deviation': drug_stdev,
    'Standard Error': drug_sem})

#print summary
drug_stats
# Out:
#                    Mean     Median   Variance  Standard Deviation  \
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774
# Ceftamin      52.591172  51.776157  39.290177            6.268188
# Infubinol     52.884795  51.820584  43.128684            6.567243
# Ketapril      55.235638  53.698743  68.553577            8.279709
# Naftisol      54.331565  52.509285  66.173479            8.134708
# Placebo       54.033581  52.288934  61.168083            7.821003
# Propriva      52.320930  50.446266  43.852013            6.622085
# Ramicane      40.216745  40.673236  23.486704            4.846308
# Stelasyn      54.233149  52.431737  59.450562            7.710419
# Zoniferol     53.236507  51.818479  48.533355            6.966589
#
#               Standard Error
# Drug Regimen
# Capomulin           0.329346
# Ceftamin            0.469821
# Infubinol           0.492236
# Ketapril            0.603860
# Naftisol            0.596466
# Placebo             0.581331
# Propriva            0.544332
# Ramicane            0.320955
# Stelasyn            0.573111
# Zoniferol           0.516398

# %%
#create summary dataframe from original data using aggregation
study_stats = mouse_study_clean['Tumor Volume (mm3)'].groupby(mouse_study_clean['Drug Regimen']).agg(['mean', 'median', 'var', 'std', 'sem'])

#print summary
study_stats
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
#generate bar plot showing total number of timepoints for each drug regimen, using Pandas
ax = mouse_study_clean['Drug Regimen'].value_counts().plot(kind = 'bar', title = 'Number of Timepoints for each Drug Regimen')
ax.set_ylabel('Number of Timepoints')

#print plot and clear variables
plt.show()

# %%
#generate bar plot showing total number of timepoints for each drug regimen, using pyplot

#create series of data
regimen = mouse_study_clean['Drug Regimen'].unique()
regimen_counts = mouse_study_clean['Drug Regimen'].value_counts()

#format x axis
x_axis = np.arange(len(regimen_counts))
tick_locations = [value for value in x_axis]

#generate plot
plt.bar(x_axis, regimen_counts)

#format lables
plt.xticks(tick_locations, regimen, rotation = 'vertical')
plt.title('Number of Timepoints for each Drug Regimen')
plt.ylabel('Number of Timepoints')

#print plot and clear variables
plt.show()

# %%
#generate a pie plot showing the distribution of female versus male mice, using Pandas

#gather data for each mouse
mouse_sex = mouse_study_clean[['Mouse ID', 'Sex']].drop_duplicates(['Mouse ID'])

#define format
colors = ["grey","yellowgreen"]
explode = (0.1,0)

#generate plot
ax = mouse_sex['Sex'].value_counts().plot(kind = 'pie', title = 'Sex of Mice', explode=explode, colors = colors, autopct="%1.1f%%", startangle=140)

#print plot and clear variables
plt.show()

# %%
#generate a pie plot showing the distribution of female versus male mice, using pyplot

#gather data for each mouse
mouse_sex = mouse_study_clean[['Mouse ID', 'Sex']].drop_duplicates(['Mouse ID'])
pies = mouse_sex['Sex'].unique()
pie_counts = mouse_sex['Sex'].value_counts()

#define format
colors = ["grey","yellowgreen"]
explode = (0.1,0)

#generate plot
plt.pie(pie_counts, explode=explode, labels=pies, colors=colors, autopct="%1.1f%%", startangle=140)

#format title
plt.title('Sex of Mice')
plt.ylabel('Sex')

#print plot and clear variables
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
#calculate the final tumor volume of each mouse across four of the treatment regimens: Capomulin, Ramicane, Infubinol, and Ceftamin

#get the last (greatest) timepoint for each mouse
regimen_index = mouse_study_clean.set_index('Drug Regimen')
mouse_maxtime = regimen_index.loc[['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'],['Mouse ID', 'Timepoint']].groupby('Mouse ID').max()

#merge this group df with the original dataframe
box_regimens_maxtime = pd.merge(mouse_maxtime, mouse_study_clean, how = 'left', on = ['Mouse ID', 'Timepoint'])

#print header
box_regimens_maxtime.head(500)
# Out:
#    Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0      a203         45    Infubinol  Female          20          23
# 1      a251         45    Infubinol  Female          21          25
# 2      a275         45     Ceftamin  Female          20          28
# 3      a411         45     Ramicane    Male           3          22
# 4      a444         45     Ramicane  Female          10          25
# ..      ...        ...          ...     ...         ...         ...
# 95     y769         45     Ceftamin  Female           6          27
# 96     y793         45    Capomulin    Male          17          17
# 97     y865         45     Ceftamin    Male          23          26
# 98     z578         45     Ramicane    Male          11          16
# 99     z581         45    Infubinol  Female          24          25
#
#     Tumor Volume (mm3)  Metastatic Sites
# 0            67.973419                 2
# 1            65.525743                 1
# 2            62.999356                 3
# 3            38.407618                 1
# 4            43.047543                 0
# ..                 ...               ...
# 95           68.594745                 4
# 96           31.896238                 2
# 97           64.729837                 3
# 98           30.638696                 0
# 99           62.754451                 3
#
# [100 rows x 8 columns]

# %%
#create dictionary of treatment keys paired with empty list values
volume_data = {'Capomulin' : [], 'Ramicane': [], 'Infubinol' : [], 'Ceftamin' : []}

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

#gather tumor volume data for each regimen
for drug in volume_data:
    drug_data = box_regimens_maxtime.loc[box_regimens_maxtime['Drug Regimen'] == drug,:]
    volume_data[f'{drug}'] = drug_data['Tumor Volume (mm3)']

#define quartile bounds within each regimen    
    quartiles = volume_data[drug].quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    lower_bound = round((lowerq - (1.5*iqr)), 2)
    upper_bound = round((upperq + (1.5*iqr)), 2)

#create a list of any outliers within the regimen
    outliers = [round(v, 2) for v in drug_data['Tumor Volume (mm3)'] if v < lower_bound or v > upper_bound]

#print outliers if found, and iqr ranges for each regimen
    if not outliers:
        print(f"For {drug}, tumor volumes below {lower_bound} or above {upper_bound} would be outliers. There are none in this sample.")
    else:
        print(f"For {drug}, tumor volumes below {lower_bound} or above {upper_bound} are outliers. Qualifying value(s): {outliers}")
# Out:
# For Capomulin, tumor volumes below 20.7 or above 51.83 would be outliers. There are none in this sample.
# For Ramicane, tumor volumes below 17.91 or above 54.31 would be outliers. There are none in this sample.
# For Infubinol, tumor volumes below 36.83 or above 82.74 are outliers. Qualifying value(s): [36.32]
# For Ceftamin, tumor volumes below 25.36 or above 87.67 would be outliers. There are none in this sample.

# %%
#generate a box plot of the final tumor volume of each mouse across four regimens of interest

#define outlier formatting
yellow_diamond = dict(markerfacecolor = 'y', marker = 'D')

#generate plot
plt.boxplot(volume_data.values(), labels = volume_data, flierprops = yellow_diamond)

#set y axis range
plt.ylim(20, 75)

#format labels
plt.ylabel('Tumor Volume (mm3)')
plt.title('Final Tumor Volume per Drug Regimen')

#print plot and clear variables
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
#generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

#select mouse
selected_mouse = mouse_study_clean.loc[mouse_study_clean['Mouse ID'] == 'y793',['Timepoint','Tumor Volume (mm3)']]

#generate plot
ax = selected_mouse.plot(x = 'Timepoint', y = 'Tumor Volume (mm3)', kind = 'line', title = 'Tumor Volume over Time of Mouse y793')

#format and label y axis
ax.set_xlabel('Timepoint (days)')
ax.set_ylabel('Tumor Volume (mm3)')
ax.set_ylim(20, selected_mouse['Tumor Volume (mm3)'].max()+3)

#format legend
ax.legend(loc = 'lower right', fancybox = True, borderpad = 1)

#print plot and clear variables
plt.show()

# %%
#generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

#create object of average mouse datapoints within the Capomulin regimen
scatter_regimen = regimen_index.loc[['Capomulin'],['Mouse ID','Tumor Volume (mm3)','Weight (g)']].groupby('Mouse ID').mean()

#generate plot with average tumor volume and weight
ax = scatter_regimen.plot(x = 'Weight (g)', y = 'Tumor Volume (mm3)', kind = 'scatter', title = 'Avg Tumor Volume vs Weight')

#format and label y axis
ax.set_ylim(20, scatter_regimen['Tumor Volume (mm3)'].max() + 2)
ax.set_ylabel('Average Tumor Volume (mm3)')

#print plot and clear variables
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
#calculate the correlation coefficient and linear regression model 

#define x and y values
x_values = scatter_regimen['Weight (g)']
y_values = scatter_regimen['Tumor Volume (mm3)']

#calculate and print correlation coefficient
correlation = st.pearsonr(x_values, y_values)
print(f"\nThe correlation between weight and average tumor volume is {round(correlation[0], 2)}\n")

#calculate linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

#define linear regression
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

#generate scatter plot
plt.scatter(x_values, y_values)

#format y axis
plt.ylim(20, y_values.max() + 2)

#generate regression line
plt.plot(x_values, regress_values,"r-")

#format labels
plt.annotate(line_eq, (18,37), fontsize=15, color="red")
plt.title('Avg Tumor Volume vs Weight')
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')

#print plot and clear variables
plt.show()
# Out:
# The correlation between weight and average tumor volume is 0.84
